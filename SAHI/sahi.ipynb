# %%
# %pip install sahi
# Out:
# WARNING: Ignoring invalid distribution ~ransformers (/home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~ransformers (/home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages)
# ...
#   Using cached fire-0.7.0.tar.gz (87 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached pybboxes-0.1.6-py3-none-any.whl.metadata (9.9 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 4.9 MB/s eta 0:00:00
# Using cached pybboxes-0.1.6-py3-none-any.whl (24 kB)
# ...
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=c40942c9a0e722a174db6a7348bd7c011d7cb5ce7ec0365f312b8a5694357274
#   Stored in directory: /home/shataxi.dubey/.cache/pip/wheels/46/54/24/1624fd5b8674eb1188623f7e8e17cdf7c0f6c24b609dfb8a89
# Successfully built fire
# WARNING: Ignoring invalid distribution ~ransformers (/home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages)
# ...

# %%
import numpy as np
import pandas as pd

import os
import torch
import matplotlib.pyplot as plt

from PIL import Image, ImageEnhance
from glob import glob

gpu_id = 1
os.environ['CUDA_VISIBLE_DEVICES'] = str(gpu_id)
bounding_box_size = 100

torch.cuda.empty_cache()

# %%
from sahi import slicing
# gr_imgs_path = '/home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/data/vlm_data/lucknow_airshed_most_15/images/*'
gr_imgs_path = '/home/shataxi.dubey/shataxi_work/vlm_on_planet/lucknow_high_resolution_zoom17/*'
image_path = glob(gr_imgs_path)[0]
x = slicing.slice_image(image = image_path,
                    slice_height=320, slice_width=320, overlap_height_ratio=0.2, 
                    overlap_width_ratio=0.2, output_dir = './lucknow_high_resolution_zoom17',
                    output_file_name=os.path.basename(image_path)[:-4])

# %%
# !ls /home/shataxi.dubey/shataxi_work/vlm_on_planet/SAHI/lucknow_high_resolution_zoom17 | wc -l
# Out:
# 100

# %%
x.sliced_image_list[1].starting_pixel
# Out:
# [256, 0]

# %%
plt.imshow(x.sliced_image_list[0].image)

# %%
# slicing.get_slice_bboxes(2560,2560,320,320,overlap_height_ratio=0.2,overlap_width_ratio=0.2) # remember here we have an overlap of 64 pixels but stride of 320-64 = 256 pixels

# %%
plt.imshow(x.images[3])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
bboxes = []
slicing.shift_bboxes(bboxes, offset = [256, 256])

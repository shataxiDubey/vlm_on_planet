# %%
# %pip install segment-geospatial
# Out:
# Collecting segment-geospatial
#   Downloading segment_geospatial-0.12.3-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: fiona in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from segment-geospatial) (1.9.6)
# Requirement already satisfied: gdown in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from segment-geospatial) (5.2.0)
# Requirement already satisfied: geopandas in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from segment-geospatial) (1.0.1)
# Requirement already satisfied: huggingface-hub in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from segment-geospatial) (0.24.3)
# Collecting ipympl (from segment-geospatial)
#   Downloading ipympl-0.9.6-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: leafmap in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from segment-geospatial) (0.38.0)
# Collecting localtileserver (from segment-geospatial)
#   Downloading localtileserver-0.10.6-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: matplotlib in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from segment-geospatial) (3.8.4)
# Requirement already satisfied: opencv-python-headless in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from segment-geospatial) (4.8.0.74)
# Collecting patool (from segment-geospatial)
#   Downloading patool-3.1.0-py2.py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: pycocotools in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from segment-geospatial) (2.0.7)
# Requirement already satisfied: pyproj in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from segment-geospatial) (3.6.1)
# Requirement already satisfied: rasterio in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from segment-geospatial) (1.3.10)
# Requirement already satisfied: rioxarray in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from segment-geospatial) (0.17.0)
# Collecting sam2 (from segment-geospatial)
#   Downloading sam2-1.1.0.tar.gz (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.8/152.8 kB 6.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: scikit-image in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from segment-geospatial) (0.23.2)
# Requirement already satisfied: scikit-learn in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from segment-geospatial) (1.3.2)
# Collecting segment-anything-hq (from segment-geospatial)
#   Downloading segment_anything_hq-0.3-py3-none-any.whl.metadata (17 kB)
# Collecting segment-anything-py (from segment-geospatial)
#   Downloading segment_anything_py-1.0.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: timm in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from segment-geospatial) (1.0.8)
# Requirement already satisfied: tqdm in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from segment-geospatial) (4.65.2)
# Requirement already satisfied: xarray in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from segment-geospatial) (2023.12.0)
# Requirement already satisfied: xyzservices in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from segment-geospatial) (2024.9.0)
# Requirement already satisfied: attrs>=19.2.0 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from fiona->segment-geospatial) (23.2.0)
# Requirement already satisfied: certifi in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from fiona->segment-geospatial) (2023.7.22)
# Requirement already satisfied: click~=8.0 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from fiona->segment-geospatial) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from fiona->segment-geospatial) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from fiona->segment-geospatial) (0.7.2)
# Requirement already satisfied: six in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from fiona->segment-geospatial) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from gdown->segment-geospatial) (4.12.3)
# Requirement already satisfied: filelock in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from gdown->segment-geospatial) (3.14.0)
# Requirement already satisfied: requests[socks] in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from gdown->segment-geospatial) (2.32.3)
# Requirement already satisfied: numpy>=1.22 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from geopandas->segment-geospatial) (1.26.4)
# Requirement already satisfied: pyogrio>=0.7.2 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from geopandas->segment-geospatial) (0.9.0)
# Requirement already satisfied: packaging in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from geopandas->segment-geospatial) (24.0)
# Requirement already satisfied: pandas>=1.4.0 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from geopandas->segment-geospatial) (2.2.2)
# Requirement already satisfied: shapely>=2.0.0 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from geopandas->segment-geospatial) (2.0.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from huggingface-hub->segment-geospatial) (2023.12.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from huggingface-hub->segment-geospatial) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from huggingface-hub->segment-geospatial) (4.12.2)
# Requirement already satisfied: ipython<9 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from ipympl->segment-geospatial) (8.19.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from ipympl->segment-geospatial) (8.1.3)
# Requirement already satisfied: pillow in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from ipympl->segment-geospatial) (10.2.0)
# Requirement already satisfied: traitlets<6 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from ipympl->segment-geospatial) (5.14.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from matplotlib->segment-geospatial) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from matplotlib->segment-geospatial) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from matplotlib->segment-geospatial) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from matplotlib->segment-geospatial) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from matplotlib->segment-geospatial) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from matplotlib->segment-geospatial) (2.9.0.post0)
# Requirement already satisfied: anywidget>=0.9.13 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from leafmap->segment-geospatial) (0.9.13)
# Requirement already satisfied: bqplot>=0.12.43 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from leafmap->segment-geospatial) (0.12.43)
# Requirement already satisfied: colour>=0.1.5 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from leafmap->segment-geospatial) (0.1.5)
# Requirement already satisfied: folium>=0.14.0 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from leafmap->segment-geospatial) (0.17.0)
# Requirement already satisfied: geojson>=3.1.0 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from leafmap->segment-geospatial) (3.1.0)
# Requirement already satisfied: ipyevents>=2.0.2 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from leafmap->segment-geospatial) (2.0.2)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from leafmap->segment-geospatial) (0.6.0)
# Requirement already satisfied: ipyleaflet>=0.18.2 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from leafmap->segment-geospatial) (0.19.2)
# Requirement already satisfied: ipyvuetify>=1.9.4 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from leafmap->segment-geospatial) (1.10.0)
# Requirement already satisfied: plotly>=5.15.0 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from leafmap->segment-geospatial) (5.24.1)
# Requirement already satisfied: pyshp>=2.3.1 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from leafmap->segment-geospatial) (2.3.1)
# Requirement already satisfied: pystac-client>=0.8.2 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from leafmap->segment-geospatial) (0.8.3)
# Requirement already satisfied: python-box>=7.2.0 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from leafmap->segment-geospatial) (7.2.0)
# Requirement already satisfied: scooby>=0.10.0 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from leafmap->segment-geospatial) (0.10.0)
# Requirement already satisfied: setuptools>=71.0.4 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from leafmap->segment-geospatial) (75.1.0)
# Requirement already satisfied: whiteboxgui>=2.3.0 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from leafmap->segment-geospatial) (2.3.0)
# Requirement already satisfied: duckdb>=0.10.3 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from leafmap->segment-geospatial) (1.1.1)
# Collecting flask<4,>=2.0.0 (from localtileserver->segment-geospatial)
#   Downloading flask-3.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting Flask-Caching (from localtileserver->segment-geospatial)
#   Downloading Flask_Caching-2.3.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting flask-cors (from localtileserver->segment-geospatial)
#   Downloading Flask_Cors-5.0.0-py2.py3-none-any.whl.metadata (5.5 kB)
# Collecting flask-restx>=1.3.0 (from localtileserver->segment-geospatial)
#   Downloading flask_restx-1.3.0-py2.py3-none-any.whl.metadata (9.3 kB)
# Collecting rio-tiler (from localtileserver->segment-geospatial)
#   Downloading rio_tiler-7.3.0-py3-none-any.whl.metadata (12 kB)
# Collecting rio-cogeo (from localtileserver->segment-geospatial)
#   Downloading rio_cogeo-5.4.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting server-thread (from localtileserver->segment-geospatial)
#   Downloading server_thread-0.3.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting werkzeug (from localtileserver->segment-geospatial)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: affine in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from rasterio->segment-geospatial) (2.4.0)
# Requirement already satisfied: snuggs>=1.4.1 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from rasterio->segment-geospatial) (1.4.7)
# Requirement already satisfied: torch>=2.5.1 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from sam2->segment-geospatial) (2.5.1)
# Requirement already satisfied: torchvision>=0.20.1 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from sam2->segment-geospatial) (0.20.1)
# Collecting tqdm (from segment-geospatial)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting hydra-core>=1.3.2 (from sam2->segment-geospatial)
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting iopath>=0.1.10 (from sam2->segment-geospatial)
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 10.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy>=1.9 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from scikit-image->segment-geospatial) (1.11.4)
# Requirement already satisfied: networkx>=2.8 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from scikit-image->segment-geospatial) (3.3)
# Requirement already satisfied: imageio>=2.33 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from scikit-image->segment-geospatial) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from scikit-image->segment-geospatial) (2024.5.10)
# Requirement already satisfied: lazy-loader>=0.4 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from scikit-image->segment-geospatial) (0.4)
# Requirement already satisfied: joblib>=1.1.1 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from scikit-learn->segment-geospatial) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from scikit-learn->segment-geospatial) (3.2.0)
# Requirement already satisfied: safetensors in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from timm->segment-geospatial) (0.4.3)
# Requirement already satisfied: psygnal>=0.8.1 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from anywidget>=0.9.13->leafmap->segment-geospatial) (0.11.1)
# Requirement already satisfied: traittypes>=0.0.6 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from bqplot>=0.12.43->leafmap->segment-geospatial) (0.2.1)
# Requirement already satisfied: Jinja2>=3.1.2 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from flask<4,>=2.0.0->localtileserver->segment-geospatial) (3.1.4)
# Collecting itsdangerous>=2.2 (from flask<4,>=2.0.0->localtileserver->segment-geospatial)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting blinker>=1.9 (from flask<4,>=2.0.0->localtileserver->segment-geospatial)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting aniso8601>=0.82 (from flask-restx>=1.3.0->localtileserver->segment-geospatial)
#   Downloading aniso8601-10.0.0-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: jsonschema in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from flask-restx>=1.3.0->localtileserver->segment-geospatial) (4.23.0)
# Requirement already satisfied: pytz in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from flask-restx>=1.3.0->localtileserver->segment-geospatial) (2024.1)
# Collecting importlib-resources (from flask-restx>=1.3.0->localtileserver->segment-geospatial)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: branca>=0.6.0 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from folium>=0.14.0->leafmap->segment-geospatial) (0.7.2)
# Collecting omegaconf<2.4,>=2.2 (from hydra-core>=1.3.2->sam2->segment-geospatial)
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core>=1.3.2->sam2->segment-geospatial)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 16.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting portalocker (from iopath>=0.1.10->sam2->segment-geospatial)
#   Downloading portalocker-3.1.1-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: jupyter-leaflet<0.20,>=0.19 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from ipyleaflet>=0.18.2->leafmap->segment-geospatial) (0.19.2)
# Requirement already satisfied: decorator in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from ipython<9->ipympl->segment-geospatial) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from ipython<9->ipympl->segment-geospatial) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from ipython<9->ipympl->segment-geospatial) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from ipython<9->ipympl->segment-geospatial) (3.0.42)
# Requirement already satisfied: pygments>=2.4.0 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from ipython<9->ipympl->segment-geospatial) (2.17.2)
# Requirement already satisfied: stack-data in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from ipython<9->ipympl->segment-geospatial) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from ipython<9->ipympl->segment-geospatial) (4.8.0)
# Requirement already satisfied: ipyvue<2,>=1.7 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from ipyvuetify>=1.9.4->leafmap->segment-geospatial) (1.11.1)
# Requirement already satisfied: comm>=0.1.3 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (0.2.1)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (4.0.11)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (3.0.11)
# Requirement already satisfied: tzdata>=2022.7 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas->segment-geospatial) (2024.1)
# Requirement already satisfied: tenacity>=6.2.0 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from plotly>=5.15.0->leafmap->segment-geospatial) (8.2.3)
# Requirement already satisfied: pystac>=1.10.0 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from pystac[validation]>=1.10.0->pystac-client>=0.8.2->leafmap->segment-geospatial) (1.10.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from requests[socks]->gdown->segment-geospatial) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from requests[socks]->gdown->segment-geospatial) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from requests[socks]->gdown->segment-geospatial) (1.26.18)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torch>=2.5.1->sam2->segment-geospatial) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torch>=2.5.1->sam2->segment-geospatial) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torch>=2.5.1->sam2->segment-geospatial) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torch>=2.5.1->sam2->segment-geospatial) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torch>=2.5.1->sam2->segment-geospatial) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torch>=2.5.1->sam2->segment-geospatial) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torch>=2.5.1->sam2->segment-geospatial) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torch>=2.5.1->sam2->segment-geospatial) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torch>=2.5.1->sam2->segment-geospatial) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torch>=2.5.1->sam2->segment-geospatial) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torch>=2.5.1->sam2->segment-geospatial) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torch>=2.5.1->sam2->segment-geospatial) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torch>=2.5.1->sam2->segment-geospatial) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torch>=2.5.1->sam2->segment-geospatial) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from sympy==1.13.1->torch>=2.5.1->sam2->segment-geospatial) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from werkzeug->localtileserver->segment-geospatial) (2.1.3)
# Requirement already satisfied: ipytree in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from whiteboxgui>=2.3.0->leafmap->segment-geospatial) (0.2.2)
# Requirement already satisfied: whitebox in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from whiteboxgui>=2.3.0->leafmap->segment-geospatial) (2.3.5)
# Requirement already satisfied: soupsieve>1.2 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from beautifulsoup4->gdown->segment-geospatial) (2.5)
# Collecting cachelib<0.10.0,>=0.9.0 (from Flask-Caching->localtileserver->segment-geospatial)
#   Downloading cachelib-0.9.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from requests[socks]->gdown->segment-geospatial) (1.7.1)
# Collecting morecantile<7.0,>=5.0 (from rio-cogeo->localtileserver->segment-geospatial)
#   Downloading morecantile-6.2.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pydantic~=2.0 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from rio-cogeo->localtileserver->segment-geospatial) (2.9.2)
# Requirement already satisfied: cachetools in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from rio-tiler->localtileserver->segment-geospatial) (5.3.2)
# Collecting color-operations (from rio-tiler->localtileserver->segment-geospatial)
#   Downloading color_operations-0.1.6-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.0 kB)
# Requirement already satisfied: httpx in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from rio-tiler->localtileserver->segment-geospatial) (0.27.0)
# Requirement already satisfied: numexpr in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from rio-tiler->localtileserver->segment-geospatial) (2.10.1)
# Collecting uvicorn (from server-thread->localtileserver->segment-geospatial)
#   Using cached uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from jedi>=0.16->ipython<9->ipympl->segment-geospatial) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from pexpect>4.3->ipython<9->ipympl->segment-geospatial) (0.7.0)
# Requirement already satisfied: wcwidth in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython<9->ipympl->segment-geospatial) (0.2.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from pydantic~=2.0->rio-cogeo->localtileserver->segment-geospatial) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from pydantic~=2.0->rio-cogeo->localtileserver->segment-geospatial) (2.23.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from jsonschema->flask-restx>=1.3.0->localtileserver->segment-geospatial) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from jsonschema->flask-restx>=1.3.0->localtileserver->segment-geospatial) (0.32.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from jsonschema->flask-restx>=1.3.0->localtileserver->segment-geospatial) (0.16.2)
# Requirement already satisfied: anyio in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from httpx->rio-tiler->localtileserver->segment-geospatial) (4.4.0)
# Requirement already satisfied: httpcore==1.* in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from httpx->rio-tiler->localtileserver->segment-geospatial) (1.0.5)
# Requirement already satisfied: sniffio in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from httpx->rio-tiler->localtileserver->segment-geospatial) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from httpcore==1.*->httpx->rio-tiler->localtileserver->segment-geospatial) (0.14.0)
# Requirement already satisfied: executing>=1.2.0 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from stack-data->ipython<9->ipympl->segment-geospatial) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from stack-data->ipython<9->ipympl->segment-geospatial) (2.4.1)
# Requirement already satisfied: pure-eval in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from stack-data->ipython<9->ipympl->segment-geospatial) (0.2.2)
# Downloading segment_geospatial-0.12.3-py2.py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.8/73.8 kB 16.9 MB/s eta 0:00:00
# Downloading ipympl-0.9.6-py3-none-any.whl (515 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.7/515.7 kB 10.6 MB/s eta 0:00:0000:01
# Downloading localtileserver-0.10.6-py3-none-any.whl (17.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 15.3 MB/s eta 0:00:0000:0100:01
# Downloading patool-3.1.0-py2.py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.4/98.4 kB 22.4 MB/s eta 0:00:00
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading segment_anything_hq-0.3-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 14.9 MB/s eta 0:00:00
# Downloading segment_anything_py-1.0.1-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 10.3 MB/s eta 0:00:00
# Downloading flask-3.1.0-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.0/103.0 kB 19.4 MB/s eta 0:00:00
# Downloading flask_restx-1.3.0-py2.py3-none-any.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 18.1 MB/s eta 0:00:0000:0100:01
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 22.7 MB/s eta 0:00:00
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 21.7 MB/s eta 0:00:00
# Downloading Flask_Caching-2.3.0-py3-none-any.whl (28 kB)
# Downloading Flask_Cors-5.0.0-py2.py3-none-any.whl (14 kB)
# Downloading rio_cogeo-5.4.1-py3-none-any.whl (20 kB)
# Downloading rio_tiler-7.3.0-py3-none-any.whl (265 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.9/265.9 kB 9.0 MB/s eta 0:00:00
# Downloading server_thread-0.3.0-py3-none-any.whl (6.6 kB)
# Downloading aniso8601-10.0.0-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 14.4 MB/s eta 0:00:00
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading cachelib-0.9.0-py3-none-any.whl (15 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading morecantile-6.2.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 13.2 MB/s eta 0:00:00
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 23.9 MB/s eta 0:00:00
# Downloading color_operations-0.1.6-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (195 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.0/195.0 kB 21.8 MB/s eta 0:00:00
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading portalocker-3.1.1-py3-none-any.whl (19 kB)
# Using cached uvicorn-0.34.0-py3-none-any.whl (62 kB)
# Building wheels for collected packages: sam2, antlr4-python3-runtime, iopath
#   Building wheel for sam2 (pyproject.toml) ... done
#   Created wheel for sam2: filename=sam2-1.1.0-cp311-cp311-linux_x86_64.whl size=492621 sha256=066a4993d74118878af5f5743deac139283c85ea5bcd040b9c32b19fd7a9cc7b
#   Stored in directory: /home/shataxi.dubey/.cache/pip/wheels/d5/c6/ed/164df00d6a31203bc2cd1f65385761825e32a77417b90cc3c7
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144553 sha256=b677e7a0931da9da2d959b3b0e9a3a7757119dcb4a903af0687ef6e6f9127803
#   Stored in directory: /home/shataxi.dubey/.cache/pip/wheels/1a/97/32/461f837398029ad76911109f07047fde1d7b661a147c7c56d1
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31532 sha256=45d8e7e6f0c060435416bd282403c409d48f8da91b83a488d5a22c38f0396bcd
#   Stored in directory: /home/shataxi.dubey/.cache/pip/wheels/ba/5e/16/6117f8fe7e9c0c161a795e10d94645ebcf301ccbd01f66d8ec
# Successfully built sam2 antlr4-python3-runtime iopath
# Installing collected packages: antlr4-python3-runtime, aniso8601, werkzeug, uvicorn, tqdm, portalocker, patool, omegaconf, itsdangerous, importlib-resources, color-operations, cachelib, blinker, server-thread, iopath, hydra-core, flask, morecantile, flask-cors, Flask-Caching, rio-tiler, rio-cogeo, flask-restx, segment-anything-py, segment-anything-hq, sam2, localtileserver, ipympl, segment-geospatial
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.65.2
#     Uninstalling tqdm-4.65.2:
#       Successfully uninstalled tqdm-4.65.2
#   Attempting uninstall: blinker
#     Found existing installation: blinker 1.7.0
#     Uninstalling blinker-1.7.0:
#       Successfully uninstalled blinker-1.7.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# openxlab 0.1.0 requires pytz~=2023.3, but you have pytz 2024.1 which is incompatible.
# openxlab 0.1.0 requires requests~=2.28.2, but you have requests 2.32.3 which is incompatible.
# openxlab 0.1.0 requires setuptools~=60.2.0, but you have setuptools 75.1.0 which is incompatible.
# openxlab 0.1.0 requires tqdm~=4.65.0, but you have tqdm 4.67.1 which is incompatible.
# streamlit 1.29.0 requires packaging<24,>=16.8, but you have packaging 24.0 which is incompatible.
# streamlit 1.29.0 requires protobuf<5,>=3.20, but you have protobuf 5.28.1 which is incompatible.
# Successfully installed Flask-Caching-2.3.0 aniso8601-10.0.0 antlr4-python3-runtime-4.9.3 blinker-1.9.0 cachelib-0.9.0 color-operations-0.1.6 flask-3.1.0 flask-cors-5.0.0 flask-restx-1.3.0 hydra-core-1.3.2 importlib-resources-6.5.2 iopath-0.1.10 ipympl-0.9.6 itsdangerous-2.2.0 localtileserver-0.10.6 morecantile-6.2.0 omegaconf-2.3.0 patool-3.1.0 portalocker-3.1.1 rio-cogeo-5.4.1 rio-tiler-7.3.0 sam2-1.1.0 segment-anything-hq-0.3 segment-anything-py-1.0.1 segment-geospatial-0.12.3 server-thread-0.3.0 tqdm-4.67.1 uvicorn-0.34.0 werkzeug-3.1.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import leafmap
from samgeo import SamGeo, tms_to_geotiff, get_basemaps

# %%
# m = leafmap.Map(center=[29.676840, -95.369222], zoom=19)
# m.add_basemap("SATELLITE")
# m
# Out:
# Map(center=[29.67684, -95.369222], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title',…

# %%
# if m.user_roi_bounds() is not None:
#     bbox = m.user_roi_bounds()
# else:
#     bbox = [-95.3704, 29.6762, -95.368, 29.6775]

# %%
# %pip install osgeo
# %pip install GDAL
# Out:
# Collecting GDAL
#   Using cached gdal-3.10.1.tar.gz (845 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [61 lines of output]
#       Using numpy 2.2.2
#       /tmp/pip-build-env-hsi4dq1l/overlay/lib/python3.11/site-packages/setuptools/config/_apply_pyprojecttoml.py:81: SetuptoolsWarning: `extras_require` overwritten in `pyproject.toml` (optional-dependencies)
#         corresp(dist, value, root_dir)
#       running egg_info
#       writing gdal-utils/GDAL.egg-info/PKG-INFO
#       writing dependency_links to gdal-utils/GDAL.egg-info/dependency_links.txt
#       writing entry points to gdal-utils/GDAL.egg-info/entry_points.txt
#       writing requirements to gdal-utils/GDAL.egg-info/requires.txt
#       writing top-level names to gdal-utils/GDAL.egg-info/top_level.txt
#       Traceback (most recent call last):
#         File "/home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 353, in <module>
#           main()
#         File "/home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 118, in get_requires_for_build_wheel
#           return hook(config_settings)
#                  ^^^^^^^^^^^^^^^^^^^^^
#         File "/tmp/pip-build-env-hsi4dq1l/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 334, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=[])
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/tmp/pip-build-env-hsi4dq1l/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 304, in _get_build_requires
#           self.run_setup()
#         File "/tmp/pip-build-env-hsi4dq1l/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 320, in run_setup
#           exec(code, locals())
#         File "<string>", line 437, in <module>
#         File "/tmp/pip-build-env-hsi4dq1l/overlay/lib/python3.11/site-packages/setuptools/__init__.py", line 117, in setup
#           return distutils.core.setup(**attrs)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/tmp/pip-build-env-hsi4dq1l/overlay/lib/python3.11/site-packages/setuptools/_distutils/core.py", line 186, in setup
#           return run_commands(dist)
#                  ^^^^^^^^^^^^^^^^^^
#         File "/tmp/pip-build-env-hsi4dq1l/overlay/lib/python3.11/site-packages/setuptools/_distutils/core.py", line 202, in run_commands
#           dist.run_commands()
#         File "/tmp/pip-build-env-hsi4dq1l/overlay/lib/python3.11/site-packages/setuptools/_distutils/dist.py", line 983, in run_commands
#           self.run_command(cmd)
#         File "/tmp/pip-build-env-hsi4dq1l/overlay/lib/python3.11/site-packages/setuptools/dist.py", line 999, in run_command
#           super().run_command(command)
#         File "/tmp/pip-build-env-hsi4dq1l/overlay/lib/python3.11/site-packages/setuptools/_distutils/dist.py", line 1002, in run_command
#           cmd_obj.run()
#         File "/tmp/pip-build-env-hsi4dq1l/overlay/lib/python3.11/site-packages/setuptools/command/egg_info.py", line 312, in run
#           self.find_sources()
#         File "/tmp/pip-build-env-hsi4dq1l/overlay/lib/python3.11/site-packages/setuptools/command/egg_info.py", line 320, in find_sources
#           mm.run()
#         File "/tmp/pip-build-env-hsi4dq1l/overlay/lib/python3.11/site-packages/setuptools/command/egg_info.py", line 543, in run
#           self.add_defaults()
#         File "/tmp/pip-build-env-hsi4dq1l/overlay/lib/python3.11/site-packages/setuptools/command/egg_info.py", line 581, in add_defaults
#           sdist.add_defaults(self)
#         File "/tmp/pip-build-env-hsi4dq1l/overlay/lib/python3.11/site-packages/setuptools/command/sdist.py", line 109, in add_defaults
#           super().add_defaults()
#         File "/tmp/pip-build-env-hsi4dq1l/overlay/lib/python3.11/site-packages/setuptools/_distutils/command/sdist.py", line 239, in add_defaults
#           self._add_defaults_ext()
#         File "/tmp/pip-build-env-hsi4dq1l/overlay/lib/python3.11/site-packages/setuptools/_distutils/command/sdist.py", line 323, in _add_defaults_ext
#           build_ext = self.get_finalized_command('build_ext')
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/tmp/pip-build-env-hsi4dq1l/overlay/lib/python3.11/site-packages/setuptools/_distutils/cmd.py", line 316, in get_finalized_command
#           cmd_obj.ensure_finalized()
#         File "/tmp/pip-build-env-hsi4dq1l/overlay/lib/python3.11/site-packages/setuptools/_distutils/cmd.py", line 124, in ensure_finalized
#           self.finalize_options()
#         File "<string>", line 284, in finalize_options
#       Exception: Python bindings of GDAL 3.10.1 require at least libgdal 3.10.1, but 3.3.2 was found
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Note: you may need to restart the kernel to use updated packages.

# %%
image = '/home/patel_zeel/kiln_compass_24/data/lucknow_airshed/images/9007647_3118628.tif'
# tms_to_geotiff(output=image, bbox=bbox, zoom=20, source="Satellite", overwrite=True)
# m.layers[-1].visible = False  # turn off the basemap
# m.add_raster(image, layer_name="Image")
# m

# %%
sam = SamGeo(
    model_type="vit_h",
    checkpoint="sam_vit_h_4b8939.pth",
    sam_kwargs=None,
)

# %%
mask = "segment.tif"
sam.generate(
    image, mask, batch=True, foreground=True, erosion_kernel=(3, 3), mask_multiplier=255
)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:02<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 2
#       1 mask = "segment.tif"
# ----> 2 sam.generate(
#       3     image, mask, batch=True, foreground=True, erosion_kernel=(3, 3), mask_multiplier=255
#       4 )
#
# File ~/miniconda3/envs/shataxi_space/lib/python3.11/site-packages/samgeo/samgeo.py:203, in SamGeo.generate(self, source, output, foreground, batch, batch_sample_size, batch_nodata_threshold, nodata_value, erosion_kernel, mask_multiplier, unique, min_size, max_size, **kwargs)
#     201     self.source = source
#     202     self.masks = output
# --> 203     return tiff_to_tiff(
#     204         source,
#     205         output,
#     206         self,
#     207         foreground=foreground,
#     208         sample_size=batch_sample_size,
#     209         sample_nodata_threshold=batch_nodata_threshold,
#     210         nodata_value=nodata_value,
#     211         erosion_kernel=erosion_kernel,
#     212         mask_multiplier=mask_multiplier,
#     213         **kwargs,
#     214     )
#     216 image = cv2.imread(source)
#     217 image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#
# File ~/miniconda3/envs/shataxi_space/lib/python3.11/site-packages/samgeo/common.py:1201, in tiff_to_tiff(src_fp, dst_fp, func, data_to_rgb, sample_size, sample_nodata_threshold, nodata_value, sample_resize, bound, foreground, erosion_kernel, mask_multiplier, **kwargs)
#    1196     uint8_rgb_in = cv2.resize(
#    1197         uint8_rgb_in, resize_hw, interpolation=cv2.INTER_LINEAR
#    1198     )
#    1200 # Run the model, call the __call__ method of SamGeo class
# -> 1201 uin8_out = func(
#    1202     uint8_rgb_in,
#    1203     foreground=foreground,
#    1204     erosion_kernel=erosion_kernel,
#    1205     mask_multiplier=mask_multiplier,
#    1206     **kwargs,
#    1207 )
#    1209 if resize_hw is not None:
#    1210     uin8_out = cv2.resize(
#    1211         uin8_out, orig_size, interpolation=cv2.INTER_NEAREST
#    1212     )
#
# File ~/miniconda3/envs/shataxi_space/lib/python3.11/site-packages/samgeo/samgeo.py:126, in SamGeo.__call__(self, image, foreground, erosion_kernel, mask_multiplier, **kwargs)
#     114 """Generate masks for the input tile. This function originates from the segment-anything-eo repository.
#     115     See https://bit.ly/41pwiHw
#     116
#    (...)
#     122         You can use this parameter to scale the mask to a larger range, for example [0, 255]. Defaults to 255.
#     123 """
#     124 h, w, _ = image.shape
# --> 126 masks = self.mask_generator.generate(image)
#     128 if foreground:  # Extract foreground objects only
#     129     resulting_mask = np.zeros((h, w), dtype=np.uint8)
#
# File ~/miniconda3/envs/shataxi_space/lib/python3.11/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/miniconda3/envs/shataxi_space/lib/python3.11/site-packages/segment_anything/automatic_mask_generator.py:163, in SamAutomaticMaskGenerator.generate(self, image)
#     138 """
#     139 Generates masks for the given image.
#     140
#    (...)
#     159          the mask, given in XYWH format.
#     160 """
#     162 # Generate masks
# --> 163 mask_data = self._generate_masks(image)
#     165 # Filter small disconnected regions and holes in masks
#     166 if self.min_mask_region_area > 0:
#
# File ~/miniconda3/envs/shataxi_space/lib/python3.11/site-packages/segment_anything/automatic_mask_generator.py:206, in SamAutomaticMaskGenerator._generate_masks(self, image)
#     204 data = MaskData()
#     205 for crop_box, layer_idx in zip(crop_boxes, layer_idxs):
# --> 206     crop_data = self._process_crop(image, crop_box, layer_idx, orig_size)
#     207     data.cat(crop_data)
#     209 # Remove duplicate masks between crops
#
# File ~/miniconda3/envs/shataxi_space/lib/python3.11/site-packages/segment_anything/automatic_mask_generator.py:251, in SamAutomaticMaskGenerator._process_crop(self, image, crop_box, crop_layer_idx, orig_size)
#     248 self.predictor.reset_image()
#     250 # Remove duplicates within this crop.
# --> 251 keep_by_nms = batched_nms(
#     252     data["boxes"].float(),
#     253     data["iou_preds"],
#     254     torch.zeros_like(data["boxes"][:, 0]),  # categories
#     255     iou_threshold=self.box_nms_thresh,
#     256 )
#     257 data.filter(keep_by_nms)
#     259 # Return to the original image frame
#
# File ~/miniconda3/envs/shataxi_space/lib/python3.11/site-packages/torchvision/ops/boxes.py:75, in batched_nms(boxes, scores, idxs, iou_threshold)
#      73     return _batched_nms_vanilla(boxes, scores, idxs, iou_threshold)
#      74 else:
# ---> 75     return _batched_nms_coordinate_trick(boxes, scores, idxs, iou_threshold)
#
# File ~/miniconda3/envs/shataxi_space/lib/python3.11/site-packages/torch/jit/_trace.py:1444, in _script_if_tracing.<locals>.wrapper(*args, **kwargs)
#    1440 @functools.wraps(fn)
#    1441 def wrapper(*args: P.args, **kwargs: P.kwargs) -> R:
#    1442     if not is_tracing():
#    1443         # Not tracing, don't do anything
# -> 1444         return fn(*args, **kwargs)
#    1446     compiled_fn: Callable[P, R] = script(wrapper.__original_fn)  # type: ignore[attr-defined]
#    1447     return compiled_fn(*args, **kwargs)
#
# File ~/miniconda3/envs/shataxi_space/lib/python3.11/site-packages/torchvision/ops/boxes.py:94, in _batched_nms_coordinate_trick(boxes, scores, idxs, iou_threshold)
#      92 offsets = idxs.to(boxes) * (max_coordinate + torch.tensor(1).to(boxes))
#      93 boxes_for_nms = boxes + offsets[:, None]
# ---> 94 keep = nms(boxes_for_nms, scores, iou_threshold)
#      95 return keep
#
# File ~/miniconda3/envs/shataxi_space/lib/python3.11/site-packages/torchvision/ops/boxes.py:40, in nms(boxes, scores, iou_threshold)
#      38 if not torch.jit.is_scripting() and not torch.jit.is_tracing():
#      39     _log_api_usage_once(nms)
# ---> 40 _assert_has_ops()
#      41 return torch.ops.torchvision.nms(boxes, scores, iou_threshold)
#
# File ~/miniconda3/envs/shataxi_space/lib/python3.11/site-packages/torchvision/extension.py:48, in _assert_has_ops()
#      46 def _assert_has_ops():
#      47     if not _has_ops():
# ---> 48         raise RuntimeError(
#      49             "Couldn't load custom C++ ops. This can happen if your PyTorch and "
#      50             "torchvision versions are incompatible, or if you had errors while compiling "
#      51             "torchvision from source. For further information on the compatible versions, check "
#      52             "https://github.com/pytorch/vision#installation for the compatibility matrix. "
#      53             "Please check your PyTorch version with torch.__version__ and your torchvision "
#      54             "version with torchvision.__version__ and verify if they are compatible, and if not "
#      55             "please reinstall torchvision so that it matches your PyTorch install."
#      56         )
#
# RuntimeError: Couldn't load custom C++ ops. This can happen if your PyTorch and torchvision versions are incompatible, or if you had errors while compiling torchvision from source. For further information on the compatible versions, check https://github.com/pytorch/vision#installation for the compatibility matrix. Please check your PyTorch version with torch.__version__ and your torchvision version with torchvision.__version__ and verify if they are compatible, and if not please reinstall torchvision so that it matches your PyTorch install.

# %%
import torch, torchvision
print(torch.__version__)
print(torchvision.__version__)
print(torchvision.__file__)
# Out:
# 2.5.1+cu124
# 0.15.2a0
# /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages/torchvision/__init__.py

# %%
# %pip install torchvision --upgrade
# Out:
# Requirement already satisfied: torchvision in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (0.20.1)
# Requirement already satisfied: numpy in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: torch==2.5.1 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torchvision) (2.5.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torchvision) (10.2.0)
# Requirement already satisfied: filelock in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torch==2.5.1->torchvision) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torch==2.5.1->torchvision) (4.12.2)
# Requirement already satisfied: networkx in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torch==2.5.1->torchvision) (3.3)
# Requirement already satisfied: jinja2 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torch==2.5.1->torchvision) (3.1.4)
# Requirement already satisfied: fsspec in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torch==2.5.1->torchvision) (2023.12.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torch==2.5.1->torchvision) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torch==2.5.1->torchvision) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torch==2.5.1->torchvision) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torch==2.5.1->torchvision) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torch==2.5.1->torchvision) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torch==2.5.1->torchvision) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torch==2.5.1->torchvision) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torch==2.5.1->torchvision) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torch==2.5.1->torchvision) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torch==2.5.1->torchvision) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torch==2.5.1->torchvision) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torch==2.5.1->torchvision) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torch==2.5.1->torchvision) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from torch==2.5.1->torchvision) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from sympy==1.13.1->torch==2.5.1->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/shataxi.dubey/miniconda3/envs/shataxi_space/lib/python3.11/site-packages (from jinja2->torch==2.5.1->torchvision) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
vector = "segment.gpkg"
sam.tiff_to_gpkg(mask, vector, simplify_tolerance=None)

# %%
shapefile = "segment.shp"
sam.tiff_to_vector(mask, shapefile)

# %%
style = {
    "color": "#3388ff",
    "weight": 2,
    "fillColor": "#7c4185",
    "fillOpacity": 0.5,
}
m.add_vector(vector, layer_name="Vector", style=style)
m
